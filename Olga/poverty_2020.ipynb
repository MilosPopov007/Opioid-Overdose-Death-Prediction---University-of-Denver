# %%
#Read a raw data Poverty CSV
import pandas as pd
pov_df = pd.read_csv('PovertyEstimates_wide_raw_data.csv')
pov_df.head()
# Out:
#    FIPS_code Stabr       Area_name  Rural-urban_Continuum_Code_2003  \
# 0          0    US   United States                              NaN
# 1       1000    AL         Alabama                              NaN
# 2       1001    AL  Autauga County                              2.0
# 3       1003    AL  Baldwin County                              4.0
# 4       1005    AL  Barbour County                              6.0
#
#    Urban_Influence_Code_2003  Rural-urban_Continuum_Code_2013  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        2.0                              2.0
# 3                        5.0                              3.0
# 4                        6.0                              6.0
#
#    Urban_Influence_Code_2013 POVALL_2020 CI90LBALL_2020 CI90UBALL_2020  ...  \
# 0                        NaN  38,371,394     38,309,115     38,433,673  ...
# ...

# %%
#Remove columns not used in the analysis
pov_df = pov_df.drop(['CI90LBALL_2020', 'CI90UBALL_2020', 'CI90UB517P_2020','POV017_2020', 'CI90LB017_2020', 'CI90UB017_2020', 'PCTPOV017_2020', 'CI90LB017P_2020', 'CI90UB017P_2020', 'POV517_2020', 'CI90LB517_2020', 'CI90UB517_2020', 'PCTPOV517_2020', 'CI90LB517P_2020', 'CI90UB517P_2020', 'MEDHHINC_2020', 'CI90LBINC_2020', 'CI90UBINC_2020', 'POV04_2020', 'CI90LB04_2020', 'CI90UB04_2020', 'PCTPOV04_2020', 'CI90LB04P_2020', 'CI90UB04P_2020', 'CI90LBALLP_2020', 'CI90UBALLP_2020'], axis=1)
pov_df.head()
# Out:
#    FIPS_code Stabr       Area_name  Rural-urban_Continuum_Code_2003  \
# 0          0    US   United States                              NaN
# 1       1000    AL         Alabama                              NaN
# 2       1001    AL  Autauga County                              2.0
# 3       1003    AL  Baldwin County                              4.0
# 4       1005    AL  Barbour County                              6.0
#
#    Urban_Influence_Code_2003  Rural-urban_Continuum_Code_2013  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        2.0                              2.0
# 3                        5.0                              3.0
# 4                        6.0                              6.0
#
#    Urban_Influence_Code_2013 POVALL_2020  PCTPOVALL_2020
# 0                        NaN  38,371,394            11.9
# 1                        NaN     714,568            14.9
# ...

# %%
#remove the US row as the data will not be used in the analysis
pov_df = pov_df.drop(0)
pov_df.head()
# Out:
#    FIPS_code Stabr       Area_name  Rural-urban_Continuum_Code_2003  \
# 1       1000    AL         Alabama                              NaN
# 2       1001    AL  Autauga County                              2.0
# 3       1003    AL  Baldwin County                              4.0
# 4       1005    AL  Barbour County                              6.0
# 5       1007    AL     Bibb County                              1.0
#
#    Urban_Influence_Code_2003  Rural-urban_Continuum_Code_2013  \
# 1                        NaN                              NaN
# 2                        2.0                              2.0
# 3                        5.0                              3.0
# 4                        6.0                              6.0
# 5                        1.0                              1.0
#
#    Urban_Influence_Code_2013 POVALL_2020  PCTPOVALL_2020
# 1                        NaN     714,568            14.9
# 2                        2.0       6,242            11.2
# ...

# %%
#check the data quality
pov_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3194 entries, 1 to 3194
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   FIPS_code                        3194 non-null   int64
#  1   Stabr                            3194 non-null   object
#  2   Area_name                        3194 non-null   object
#  3   Rural-urban_Continuum_Code_2003  3136 non-null   float64
#  4   Urban_Influence_Code_2003        3136 non-null   float64
#  5   Rural-urban_Continuum_Code_2013  3141 non-null   float64
#  6   Urban_Influence_Code_2013        3141 non-null   float64
#  7   POVALL_2020                      3193 non-null   object
#  8   PCTPOVALL_2020                   3193 non-null   float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 249.5+ KB

# %%
#export the dataframe into csv without index
pov_df.to_csv('PovertyEstimates2020_clean.csv', index=False)
